# %% [markdown]
# <a href="https://colab.research.google.com/github/GilRtt/UTS_PCD/blob/main/AgilRahmat_UTS_PCD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from google.colab.patches import cv2_imshow  # Mengganti cv2.imshow menjadi cv2_imshow
from skimage import io
from PIL import Image

# %%
import cv2
from google.colab import drive
drive.mount('/content/drive')
from google.colab.patches import cv2_imshow

image = cv2.imread('/content/drive/MyDrive/Pengolahan Citra Digital/UTS/UTS.jpeg', cv2.IMREAD_UNCHANGED)

image_2 = cv2.cvtColor( image, cv2.COLOR_BGR2RGB)
final_frame = cv2.hconcat([image_2, image])
cv2_imshow(final_frame)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=1440x1280>

# %%
print("Ukuran gambar:", image.size)
print("Bentuk gambar:", image.shape)
print("Tipe data gambar:", image.dtype)
# Out:
# Ukuran gambar: 2764800
# Bentuk gambar: (1280, 720, 3)
# Tipe data gambar: uint8

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([[1, 2, 2, 2, 10], [10, 20, 30, 40, 50]])

print("Array a:")
print(a)
print("Ravel:")
print(a.ravel())
print("Flatten:")
print(a.flatten())

plt.hist(a.ravel(), bins=50, range=[0, 50])
plt.show()
# Out:
# Array a:
# [[ 1  2  2  2 10]
#  [10 20 30 40 50]]
# Ravel:
# [ 1  2  2  2 10 10 20 30 40 50]
# Flatten:
# [ 1  2  2  2 10 10 20 30 40 50]

# %%
plt.hist(image.ravel(), bins=256, range=[0, 256])
plt.show()

# %%
color = ('b', 'g', 'r')
for i, col in enumerate(color):
    histogram = cv2.calcHist([image], [i], None, [256], [0, 256])
    plt.plot(histogram, color=col)
    plt.xlim([0, 256])

plt.show()

# %%
color = ('b', 'g', 'r')
for i, col in enumerate(color):
    histogram = cv2.calcHist([image], [i], None, [4], [0, 256])
    plt.plot(histogram, color=col)
    plt.xlim([0, 4])

plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogram = cv2.calcHist([image], [i], None, [8], [0,256])
  plt.plot(histogram, color = col)
  plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogram = cv2.calcHist([image], [i], None, [16], [0,256])
  plt.plot(histogram, color = col)
plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogram = cv2.calcHist([image], [i], None, [32], [0,256])
  plt.plot(histogram, color = col)
plt.show()

# %%
b,g,r = cv2.split(image)
cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=L size=720x1280>

# %%
image = cv2.imread('/content/drive/MyDrive/Pengolahan Citra Digital/UTS/UTS.jpeg', cv2.IMREAD_UNCHANGED)

#blue channel
bluech = image[:,:,0]
cv2_imshow(bluech)
# Out:
# <PIL.Image.Image image mode=L size=720x1280>

# %%
plt.hist(bluech.ravel(), 16, [0, 256], color='blue')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 8, [0, 256], color='blue')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 32, [0, 256], color='blue')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 256, [0, 256], color='blue')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 4, [0, 256], color='blue')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
plt.show()

# %%
#green channel
greench = image[:,:,1]
cv2_imshow(greench)
# Out:
# <PIL.Image.Image image mode=L size=720x1280>

# %%
plt.hist(bluech.ravel(), 8, [0, 256], color='green')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 4, [0, 256], color='green')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 16, [0, 256], color='green')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 32, [0, 256], color='green')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 256, [0, 256], color='green')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
#red channel

redch = image[:,:,2]
cv2_imshow(redch)
# Out:
# <PIL.Image.Image image mode=L size=720x1280>

# %%
plt.hist(redch.ravel(), 256, [0, 256], color='red')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(redch.ravel(), 32, [0, 256], color='red')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(redch.ravel(), 16, [0, 256], color='red')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %%
plt.hist(redch.ravel(), 8, [0, 256], color='red')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %%
plt.hist(redch.ravel(), 4, [0, 256], color='red')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=720x1280>

# %%
plt.hist(gray_image.ravel(), bins = 256, range = [0,256])
plt.show()


print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 921600
# (1280, 720)
# uint8

# %%
plt.hist(gray_image.ravel(), bins = 4, range = [0,256])
plt.show()


print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 921600
# (1280, 720)
# uint8

# %%
invert_gray = 255 - gray_image
cv2_imshow(invert_gray)
# Out:
# <PIL.Image.Image image mode=L size=720x1280>

# %%
plt.hist(invert_gray.ravel(), bins = 256, range = [0,256])
plt.show()

# %%
bright_image = (100.0/255)*gray_image + 100
cv2_imshow(bright_image)
# Out:
# <PIL.Image.Image image mode=L size=720x1280>

# %%
plt.hist(bright_image.ravel(), bins = 256, range = [0,256])
plt.show()

# %%
darken_image = 255.0*(gray_image/255.0)**2
cv2_imshow(darken_image)
# Out:
# <PIL.Image.Image image mode=L size=720x1280>

# %%
plt.hist(darken_image.ravel(), bins = 256, range = [0,256])
plt.show()
